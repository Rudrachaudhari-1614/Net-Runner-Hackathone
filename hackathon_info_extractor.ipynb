# %%
import sys
sys.path.append("c:/users\chinmay\appdata\roaming\python\python311\site-packages")

# %%
# !pip install huggingface_hub
# !pip install chromadb
# !pip install langchain
# !pip install pypdf
# !pip install sentence-transformers
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
# import required libraries
# from langchain.document_loaders import PyPDFLoader\
# from langchain.loaders import DirectoryLoader
# from langchain_community.document_loaders import TextLoader
# Load the pdf file and split it into smaller chunks
# loader = PyPDFLoader("TanishaPatel_resume.pdf")
# from langchain.document_loaders import TextLoader


from langchain.text_splitter import CharacterTextSplitter
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.llms import HuggingFaceHub
from langchain.vectorstores import Chroma
from langchain.chains import ConversationalRetrievalChain
import sys



# Load the text file
loader = TextLoader("Tanisha Patel .txt")
documents = loader.load()

# Split the documents into smaller chunks
text_splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=0)
texts = text_splitter.split_documents(documents)
embeddings = HuggingFaceEmbeddings()
db = Chroma.from_documents(texts, embeddings)
retriever = db.as_retriever(search_kwargs={'k': 2})
repo_id = "mistralai/Mistral-7B-Instruct-v0.2"
llm = HuggingFaceHub(huggingfacehub_api_token='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',
                     repo_id=repo_id, model_kwargs={"temperature":0.2, "max_new_tokens":200})
qa_chain = ConversationalRetrievalChain.from_llm(llm, retriever,return_source_documents=True)

chat_history = []

# Define multiple preset queries
preset_queries = [
    "Provide Educational Details",
    "Provide Work Experience",
    "Provide all the skills",
    "Extract all the Job Titles from work experience with timeline"
]

for query in preset_queries:
    result = qa_chain({'question': query, 'chat_history': chat_history})
    print('Question:', query)

    # Extracting the relevant part of the answer
    answer = result['answer']
    helpful_index = answer.find("Helpful Answer:")
    if helpful_index != -1:
        answer = answer[helpful_index+len("Helpful Answer:"):]

    print('Answer:', answer.strip() + '\n')
    chat_history.append((query, answer.strip()))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 18
#      11 import sys
#      13 # Load the pdf file and split it into smaller chunks
#      14 # loader = PyPDFLoader("TanishaPatel_resume.pdf")
#      15 # from langchain.document_loaders import TextLoader
#      16
#      17 # Load the text file
# ---> 18 loader = TextLoader("Tanisha Patel .txt")
#      19 documents = loader.load()
#      21 # Split the documents into smaller chunks
#
# NameError: name 'TextLoader' is not defined

# %%
class LangChainDocument:
    def __init__(self, text):
        self.text = text
    
    def get_text(self):
        return self.text

def create_langchain_document(text):
    """
    Create a LangChainDocument object from text content.
    
    Args:
    - text (str): Text content.
    
    Returns:
    - LangChainDocument: LangChainDocument object.
    """
    return LangChainDocument(text)

# Example usage:
text_content = "This is an example text."
langchain_document = create_langchain_document(text_content)
print(langchain_document.get_text())
# Out:
# This is an example text.

# %%
pip install sentence-transformers
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Define the path to the text file
text_file_path = "C:/Users/chinmay/Desktop/March1_Till_Evening/29th_final/hackathon/output/rudra.txt"

# Load text from the file
with open(text_file_path, "r", encoding="utf-8") as file:
    text_content = file.read()

# Split the text into smaller chunks (if needed)
# For example, if you want to split the text into chunks of 1000 characters
chunk_size = 1000
texts = [text_content[i:i+chunk_size] for i in range(0, len(text_content), chunk_size)]

# Continue with the rest of your code
# Create embeddings and vector store
embeddings = HuggingFaceEmbeddings()
db = Chroma.from_texts(texts, embeddings)

# Create a retriever
retriever = db.as_retriever(search_kwargs={'k': 2})

# Define the Hugging Face repository ID
repo_id = "mistralai/Mistral-7B-Instruct-v0.2"

# Create a language model
llm = HuggingFaceHub(huggingfacehub_api_token='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',
                     repo_id=repo_id, model_kwargs={"temperature":0.2, "max_new_tokens":200})

# Create a conversational retrieval chain
qa_chain = ConversationalRetrievalChain.from_llm(llm, retriever, return_source_documents=True)

# Define preset queries
preset_queries = [
    "Provide Educational Details",
    "Provide Work Experience",
    "Provide all the skills",
    "Extract all the Job Titles from work experience with timeline"
]

chat_history = []

# Loop through preset queries and get answers
for query in preset_queries:
    result = qa_chain({'question': query, 'chat_history': chat_history})
    print('Question:', query)

    # Extracting the relevant part of the answer
    answer = result['answer']
    helpful_index = answer.find("Helpful Answer:")
    if helpful_index != -1:
        answer = answer[helpful_index+len("Helpful Answer:"):]

    print('Answer:', answer.strip() + '\n')
    chat_history.append((query, answer.strip()))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 15
#      11 texts = [text_content[i:i+chunk_size] for i in range(0, len(text_content), chunk_size)]
#      13 # Continue with the rest of your code
#      14 # Create embeddings and vector store
# ---> 15 embeddings = HuggingFaceEmbeddings()
#      16 db = Chroma.from_texts(texts, embeddings)
#      18 # Create a retriever
#
# NameError: name 'HuggingFaceEmbeddings' is not defined

# %%
# Define the filename for storing the information
filename = "stored_information.txt"

# Define a function to save the information to a text file
def save_information(data):
    with open(filename, 'w') as file:
        for query, answer in data.items():
            file.write(f"Question: {query}\n")
            file.write(f"Answer: {answer}\n\n")

# Initialize an empty dictionary to store the information
stored_information = {}

# Define multiple preset queries
preset_queries = [
    "Provide Educational Details",
    "Provide Work Experience",
    "Provide all the skills",
    "Extract all the Job Titles from work experience with timeline",
    "List skills"
]

# Iterate over preset queries and store the results
for query in preset_queries:
    result = qa_chain({'question': query, 'chat_history': chat_history})
    answer = result['answer']
    helpful_index = answer.find("Helpful Answer:")
    if helpful_index != -1:
        answer = answer[helpful_index+len("Helpful Answer:"):]

    stored_information[query] = answer.strip()

    # Print and store the information
    print('Question:', query)
    print('Answer:', stored_information[query] + '\n')

# Save the stored information to a text file
save_information(stored_information)

print("Information has been saved to", filename)
# Out:
# Question: Provide Educational Details
# Answer: Tanisha Patel is a 3rd-year Computer Science student at Nirma University in Ahmedabad, Gujarat, with a CGPA of 8.14. She has taken relevant coursework in Deep Learning, Natural Language Processing, Graph Theory, and Introduction to Image and Video Processing. Tanisha has also demonstrated technical skills in various programming languages such as C, C++, Java, Python, JavaScript, HTML, CSS, and SQL, as well as tools like Git, Machine Learning, Deep Learning, Bio-Inspired Algorithms, Canva, Figma, Notion, and FlutterFlow. She has also showcased strong soft skills in problem solving, accountability, time management, and ability to multi-task, as well as leadership. Tanisha has participated in several certificates programs, including the 14th International Conference on Information and Knowledge Technology 2023, Neural Networks and Deep
#
# Question: Provide Work Experience
# ...
